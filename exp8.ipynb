# %%
import numpy as np

# %%
# Simple neural network with
#   3 input neurons
#   1 output neuron

inputs = [1.2, 5.1, 2.1]
weights = [3.1, 2.1, 8.7]
bias = 3

# %%
output = np.dot(weights, inputs) + bias
print(f"Output: {output}")
# Out:
# Output: 35.7

# %%
# Neural network with one hidden layer

inputs = [1, 2, 3, 2.5]
weights1 = [0.2, 0.8, -0.5, 1.0]
weights2 = [0.5, -0.91, 0.26, -0.5]
weights3 = [-0.26, -0.27, 0.17, 0.87]
weights = [weights1, weights2, weights3]
biases = [2, 3, 0.5]

# %%
output = np.dot(inputs, np.transpose(weights)) + biases
print(f"Output: {output}")
# Out:
# Output: [4.8   1.21  2.385]

# %%
inputs=np.array([1,2,3,2.5])

# %%
# Neural network with 2 hidden layers
weights = []
# Layer 1 weights (3 neurons)
weights.append(np.array([
    [0.2, 0.8, -0.5, 1.0],
    [0.5, -0.91, 0.26, -0.5],
    [-0.26, -0.27, 0.17, 0.87],
]))
# Layer 2 weights (3 neurons)
weights.append(np.array([
    [0.1, 0.14, 0.5],
    [0.5, 0.12, 0.33],
    [0.44, 0.73, 0.13]
]))
biases = np.array([
    [2, 3, 0.5],
    [1, 2, -0.5],
])

# %%
output = np.dot(weights[0], inputs) + biases[0]
output = np.dot(weights[1], output) + biases[1]
print(f"Output: {output}")
# Out:
# Output: [2.8419  5.33225 2.80535]

# %%
# Activation function

inputs = np.array([1.2, 5.1, 2.1])
weights = np.array([3.1, 2.1, 8.7])
bias = 3

output = np.dot(inputs, weights) + bias
print(f"Output: {output}")
# Out:
# Output: 35.7

# %%
import math
def sigmoid(x):
    return 1 / (1 + math.exp(-x))

print(f"After sigmoid activation: {sigmoid(output)}")
# Out:
# After sigmoid activation: 0.9999999999999998

# %%
def tanh(x):
    return (math.exp(x) - math.exp(-x)) / (math.exp(x) + math.exp(-x))

print(f"After tanh activation: {tanh(output)}")
# Out:
# After tanh activation: 1.0

# %%
def relu(x):
    return max(0, x)

print(f"After relu activation: {relu(output)}")
# Out:
# After relu activation: 35.7
